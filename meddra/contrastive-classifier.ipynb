# %% [markdown]
# ## Train model using classification and contrastive loss

# %%
import os
import sys
import random

p = os.path.abspath('../')
sys.path.insert(1, p)

os.environ["TOKENIZERS_PARALLELISM"] = "true"
os.environ["TRANSFORMERS_NO_ADVISORY_WARNINGS"] = "1"

import transformers
transformers.logging.set_verbosity_error()

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from tqdm import tqdm
from torch.utils.data import DataLoader
import torch.nn.functional as F

import matplotlib.pyplot as plt

from datasets import Dataset, load_dataset, Split

import seaborn as sns
sns.set_theme(color_codes=True)

from transformers import DataCollatorWithPadding, AutoModelForSequenceClassification, Trainer, TrainingArguments
import evaluate

from src.contrastive_transformers.collators import TextCollator
from src.contrastive_transformers.datasets import AutoAugmentDataset
from src.contrastive_transformers.trainers import ContrastiveTrainer
from src.contrastive_transformers.losses import SupConLoss

from src.utils.utils import * 

seed = 7631
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %load_ext autoreload
# %autoreload 2

# %%
smm4h20 = load_dataset('KevinSpaghetti/smm4h20')
cadec = load_dataset('KevinSpaghetti/cadec')

meddra_ontology = pd.read_csv('./data/processed/meddra_ontology.csv')
all_pts = meddra_ontology['term_PT'].unique()

llt_pt_examples = pd.read_csv('./data/processed/llt_pt_examples.csv')
all_llts = llt_pt_examples['term_LLT'].unique()

llt_to_pt_mapping = dict(llt_pt_examples[['term_LLT', 'term_PT']].itertuples(index=False))

all_pts = load_dataset('KevinSpaghetti/all_pts', split=Split.ALL)
pt_vocab = dict(zip(all_pts['term'], all_pts['label']))
index_to_label = dict(zip(all_pts['label'], all_pts['term']))
print(len(pt_vocab))
# Out:
# Using custom data configuration KevinSpaghetti--smm4h20-9b0cef5ffb10261f
# Found cached dataset parquet (/home/kevinds/.cache/huggingface/datasets/KevinSpaghetti___parquet/KevinSpaghetti--smm4h20-9b0cef5ffb10261f/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Using custom data configuration KevinSpaghetti--cadec-d97aca76af8be810
# Found cached dataset parquet (/home/kevinds/.cache/huggingface/datasets/KevinSpaghetti___parquet/KevinSpaghetti--cadec-d97aca76af8be810/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
smm4h20_train_df = pd.DataFrame(smm4h20['train'])
cadec_train_df = pd.DataFrame(cadec['train'])
train_pairs = pd.concat([
    smm4h20_train_df[['ade', 'term_PT']],
    #cadec_train_df[['ade', 'term_PT']],
    llt_pt_examples[['term_LLT', 'term_PT']].rename({'term_LLT': 'ade'}, axis=1),
    meddra_ontology[['term_HLT', 'term_PT']].rename({'term_HLT': 'ade'}, axis=1),
    #meddra_ontology[['term_HLGT', 'term_PT']].rename({'term_HLGT': 'ade'}, axis=1),
    #meddra_ontology[['term_SOC', 'term_PT']].rename({'term_SOC': 'ade'}, axis=1),
], axis=0).reset_index(drop=True)

# %%
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
train = AutoAugmentDataset(train_pairs['ade'], train_pairs['term_PT'], return_negative=False)
collator = TextCollator(tokenizer, max_length=32, vocab=pt_vocab)

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels=len(pt_vocab),
    label2id=pt_vocab,
    id2label={pt_vocab[k]: k for k in pt_vocab},
    cache_dir='./cache/')
model.train()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=24571, bias=True)
# )

# %%
contrastive_head = nn.Sequential(
    nn.Linear(768, 768 // 2),
    nn.ReLU(),
    nn.Linear(768 // 2, 768 // 4),
    nn.ReLU(),
    nn.Linear(768 // 4, 768 // 8),
)

cl_loss = nn.CrossEntropyLoss()
ct_loss = SupConLoss(0.2)

def loss_adapter(anchor_encodings, 
                 positive_encodings, 
                 negative_encodings, 
                 labels, 
                 negative_labels, 
                 anchor_outputs, positive_outputs, negative_outputs):
    contrastive_loss = (
        ct_loss(anchor_encodings, positive_encodings, labels) + 
        ct_loss(positive_encodings, anchor_encodings, labels)
    )
    classification_loss = (
        cl_loss(anchor_outputs.get('logits'), labels) + 
        cl_loss(positive_outputs.get('logits'), labels)
    )   
    if negative_labels is not None and negative_outputs is not None:
        classification_loss = cl_loss(negative_outputs.get('logits'), negative_labels)
    
    return classification_loss + contrastive_loss

# %%
cb = StoreLosses()

training_args = TrainingArguments(
    output_dir="./models/smm4h20/contrastive-classifier",
    resume_from_checkpoint=True,
    do_train=True,
    do_eval=False,
    num_train_epochs=32,
    learning_rate=2e-5,
    disable_tqdm=False,
    per_device_train_batch_size=32,
    gradient_accumulation_steps=4,
    warmup_steps=5,
    weight_decay=0.01,
    remove_unused_columns=False,
    logging_steps=256,
    dataloader_num_workers=4,
    fp16=True,
    fp16_opt_level='03',
    report_to="none",
    optim="adamw_torch"
)

trainer = ContrastiveTrainer(
    loss=loss_adapter,
    head=contrastive_head,
    use_negatives=False,
    model=model,
    args=training_args,
    train_dataset=train,
    data_collator=collator,
    callbacks=[cb]
)

trainer.train()
# Out:
# Using cuda_amp half precision backend
# ***** Running training *****
#   Num examples = 74438
#   Num Epochs = 32
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 128
#   Gradient Accumulation steps = 4
#   Total optimization steps = 18592
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='18592' max='18592' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18592/18592 3:33:46, Epoch 31/32]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>256</td>
#       <td>133.722200</td>
#     </tr>
#     <tr>
#       <td>512</td>
#       <td>94.804400</td>
#     </tr>
#     <tr>
#       <td>768</td>
#       <td>82.717500</td>
#     </tr>
#     <tr>
#       <td>1024</td>
#       <td>76.846100</td>
#     </tr>
#     <tr>
#       <td>1280</td>
#       <td>71.746600</td>
#     </tr>
#     <tr>
#       <td>1536</td>
#       <td>67.464500</td>
#     </tr>
#     <tr>
#       <td>1792</td>
#       <td>64.933400</td>
#     </tr>
#     <tr>
#       <td>2048</td>
#       <td>62.124000</td>
#     </tr>
#     <tr>
#       <td>2304</td>
#       <td>60.016900</td>
#     </tr>
#     <tr>
#       <td>2560</td>
#       <td>57.620800</td>
#     </tr>
#     <tr>
#       <td>2816</td>
#       <td>56.120400</td>
#     </tr>
#     <tr>
#       <td>3072</td>
#       <td>54.529600</td>
#     </tr>
#     <tr>
#       <td>3328</td>
#       <td>52.773800</td>
#     </tr>
#     <tr>
#       <td>3584</td>
#       <td>51.944200</td>
#     </tr>
#     <tr>
#       <td>3840</td>
#       <td>50.592600</td>
#     </tr>
#     <tr>
#       <td>4096</td>
#       <td>49.817300</td>
#     </tr>
#     <tr>
#       <td>4352</td>
#       <td>48.454300</td>
#     </tr>
#     <tr>
#       <td>4608</td>
#       <td>47.731500</td>
#     </tr>
#     <tr>
#       <td>4864</td>
#       <td>46.709600</td>
#     </tr>
#     <tr>
#       <td>5120</td>
#       <td>45.988000</td>
#     </tr>
#     <tr>
#       <td>5376</td>
#       <td>45.309200</td>
#     </tr>
#     <tr>
#       <td>5632</td>
#       <td>44.568000</td>
#     </tr>
#     <tr>
#       <td>5888</td>
#       <td>43.985800</td>
#     </tr>
#     <tr>
#       <td>6144</td>
#       <td>43.389100</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>42.994000</td>
#     </tr>
#     <tr>
#       <td>6656</td>
#       <td>42.214600</td>
#     </tr>
#     <tr>
#       <td>6912</td>
#       <td>41.926500</td>
#     </tr>
#     <tr>
#       <td>7168</td>
#       <td>41.510900</td>
#     </tr>
#     <tr>
#       <td>7424</td>
#       <td>40.973100</td>
#     </tr>
#     <tr>
#       <td>7680</td>
#       <td>40.814600</td>
#     </tr>
#     <tr>
#       <td>7936</td>
#       <td>40.225900</td>
#     </tr>
#     <tr>
#       <td>8192</td>
#       <td>39.976100</td>
#     </tr>
#     <tr>
#       <td>8448</td>
#       <td>39.602700</td>
#     </tr>
#     <tr>
#       <td>8704</td>
#       <td>39.172600</td>
#     </tr>
#     <tr>
#       <td>8960</td>
#       <td>38.696300</td>
#     </tr>
#     <tr>
#       <td>9216</td>
#       <td>38.758400</td>
#     </tr>
#     <tr>
#       <td>9472</td>
#       <td>38.487600</td>
#     </tr>
#     <tr>
#       <td>9728</td>
#       <td>37.954700</td>
#     </tr>
#     <tr>
#       <td>9984</td>
#       <td>37.960900</td>
#     </tr>
#     <tr>
#       <td>10240</td>
#       <td>37.594200</td>
#     </tr>
#     <tr>
#       <td>10496</td>
#       <td>37.452600</td>
#     </tr>
#     <tr>
#       <td>10752</td>
#       <td>37.203500</td>
#     </tr>
#     <tr>
#       <td>11008</td>
#       <td>36.937700</td>
#     </tr>
#     <tr>
#       <td>11264</td>
#       <td>36.794800</td>
#     </tr>
#     <tr>
#       <td>11520</td>
#       <td>36.575100</td>
#     </tr>
#     <tr>
#       <td>11776</td>
#       <td>36.490800</td>
#     </tr>
#     <tr>
#       <td>12032</td>
#       <td>36.198000</td>
#     </tr>
#     <tr>
#       <td>12288</td>
#       <td>35.920100</td>
#     </tr>
#     <tr>
#       <td>12544</td>
#       <td>35.722800</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>35.964400</td>
#     </tr>
#     <tr>
#       <td>13056</td>
#       <td>35.514800</td>
#     </tr>
#     <tr>
#       <td>13312</td>
#       <td>35.559500</td>
#     </tr>
#     <tr>
#       <td>13568</td>
#       <td>35.452700</td>
#     </tr>
#     <tr>
#       <td>13824</td>
#       <td>35.291000</td>
#     </tr>
#     <tr>
#       <td>14080</td>
#       <td>35.348100</td>
#     </tr>
#     <tr>
#       <td>14336</td>
#       <td>35.032500</td>
#     </tr>
#     <tr>
#       <td>14592</td>
#       <td>34.940600</td>
#     </tr>
#     <tr>
#       <td>14848</td>
#       <td>34.788600</td>
#     </tr>
#     <tr>
#       <td>15104</td>
#       <td>35.022300</td>
#     </tr>
#     <tr>
#       <td>15360</td>
#       <td>34.678400</td>
#     </tr>
#     <tr>
#       <td>15616</td>
#       <td>34.644000</td>
#     </tr>
#     <tr>
#       <td>15872</td>
#       <td>34.665600</td>
#     </tr>
#     <tr>
#       <td>16128</td>
#       <td>34.407600</td>
#     </tr>
#     <tr>
#       <td>16384</td>
#       <td>34.493100</td>
#     </tr>
#     <tr>
#       <td>16640</td>
#       <td>34.204400</td>
#     </tr>
#     <tr>
#       <td>16896</td>
#       <td>34.335400</td>
#     </tr>
#     <tr>
#       <td>17152</td>
#       <td>34.428700</td>
#     </tr>
#     <tr>
#       <td>17408</td>
#       <td>34.144000</td>
#     </tr>
#     <tr>
#       <td>17664</td>
#       <td>34.299900</td>
#     </tr>
#     <tr>
#       <td>17920</td>
#       <td>34.231200</td>
#     </tr>
#     <tr>
#       <td>18176</td>
#       <td>34.311500</td>
#     </tr>
#     <tr>
#       <td>18432</td>
#       <td>34.063600</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-1000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-1000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-1500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-1500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-2000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-2000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-2500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-2500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-2500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-3000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-3000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-3500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-3500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-3500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-4000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-4000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-4500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-4500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-5000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-5000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-5500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-5500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-5500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-6000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-6000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-6500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-6500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-6500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-7000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-7000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-7000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-7500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-7500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-7500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-8000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-8000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-8000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-8500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-8500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-8500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-9000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-9000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-9000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-9500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-9500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-9500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-10000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-10000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-10500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-10500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-10500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-11000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-11000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-11000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-11500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-11500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-11500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-12000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-12000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-12000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-12500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-12500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-12500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-13000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-13000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-13000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-13500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-13500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-13500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-14000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-14000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-14000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-14500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-14500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-14500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-15000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-15000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-15000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-15500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-15500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-15500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-16000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-16000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-16000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-16500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-16500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-16500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-17000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-17000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-17000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-17500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-17500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-17500/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-18000
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-18000/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-18000/pytorch_model.bin
# Saving model checkpoint to ./models/smm4h20/contrastive-classifier/checkpoint-18500
# Configuration saved in ./models/smm4h20/contrastive-classifier/checkpoint-18500/config.json
# Model weights saved in ./models/smm4h20/contrastive-classifier/checkpoint-18500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=18592, training_loss=44.657053988484634, metrics={'train_runtime': 12827.7479, 'train_samples_per_second': 185.692, 'train_steps_per_second': 1.449, 'total_flos': 0.0, 'train_loss': 44.657053988484634, 'epoch': 32.0})

# %%
fig = plt.figure(figsize=(6, 6))
contr_ax = plt.subplot()
contr_ax.set_title("contrastive loss")
sns.lineplot(x=range(1, len(cb.train_loss) + 1), y=cb.train_loss, ax=contr_ax)

fig.show()
